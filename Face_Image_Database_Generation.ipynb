# %% [markdown]
# <a href="https://colab.research.google.com/github/Sejal-2002/Projects/blob/main/Face_Image_Database_Generation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import cv2 
from PIL import Image
from skimage import io
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
img=io.imread('mpw.jpg')
plt.imshow(img)

# %%
test_image_gray=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

# %%
plt.imshow(test_image_gray,cmap='gray')

# %%
def convertToRGB(img):
    return cv2.cvtColor(img,cv2.COLOR_BG2BGR)

# %%
haar_cascade_face=cv2.CascadeClassifier('haarcascade_frontalface_default.xml')

# %%
haar_cascade_face=cv2.CascadeClassifier('haarcascade_eye.xml')

# %%
faces_rects=haar_cascade_face.detectMultiScale(test_image_gray,scaleFactor=1.2,minNeighbors=5);

# %%
print('Face found:',len(faces_rects))
# Out:
# Face found: 5

# %%
test_image=cv2.imread('mpw.jpg')

# %%
for (x,y,w,h) in faces_rects:
  cv2.rectangle(test_image,(x,y),(x+w,y+h),(0,255,0),4)

# %%
print(x,y,h,w)
# Out:
# 242 101 22 22

# %%
print('shape of image',img.shape)
# Out:
# shape of image (339, 509, 3)

# %%
import cv2

# Create a CascadeClassifier Object
face_cascade = cv2.CascadeClassifier("haarcascade_frontalface_default.xml")
eye_cascade = cv2.CascadeClassifier('haarcascade_eye.xml')
# Reading the image as it is
img = cv2.imread("mpw.jpg")

# Reading the image as gray scale image

gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)#cv2.cvtColor() method is used to convert an image from one color space to another
face_cascade=cv2.CascadeClassifier('haarcascade_frontalface_alt2.xml')
faces = face_cascade.detectMultiScale(gray, 1.3, 5) #We use CascadeClassifier.detectMultiScale() to find faces or eyes, and it is defined like

# Search the co-ordintes of the image
for (x,y,w,h) in faces:
    cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
    roi_gray = gray[y:y+h, x:x+w]
    roi_color = img[y:y+h, x:x+w]
    eyes = eye_cascade.detectMultiScale(roi_gray)
    for (ex,ey,ew,eh) in eyes:
        cv2.rectangle(roi_color,(ex,ey),(ex+ew,ey+eh),(0,255,0),2)



cv2_imshow( img)
# Out:
# <PIL.Image.Image image mode=RGB size=509x339 at 0x7F091C5CDA50>

# %%
crop=img[y:y+h,x:x+w]

# %%
plt.imshow(crop)
